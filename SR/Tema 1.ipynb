# %% [markdown]
# ##### Se da un sistem RSA cu modul public de criptare $n$ ($n=p*q$ cu $p$ si $q$ prime), modul de exponentiere $e=65537$ si modul de decriptare $d$. Stiind valoarea $g=d*(p-17)$, factorizati numarul $n$.
#
# Hint: Euler Theorem, Fermat's little theorem.
#
# $n$ este
# ...
#
# $e$ este
# 65537
#
# $g=d*(p-17)$ este
# ...

# %%
n = ...

g = ...

e = 65537

# %%
p_minus_17 = pow(g, e) % n
p_minus_17

# %%
1+2
# Out:
# 3

# %%
import Crypto.Util.number as num

# %%
num.
# Out:
# <module 'Crypto.Util' from 'C:\\Users\\Ciprian Mihai\\Anaconda3\\lib\\site-packages\\Crypto\\Util\\__init__.py'>
