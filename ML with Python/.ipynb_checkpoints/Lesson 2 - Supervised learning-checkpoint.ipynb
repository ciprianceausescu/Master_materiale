# %%
### Loading data

# %%
# %matplotlib inline
from preamble import *

# %% [markdown]
# ### Import make_forge dataset

# %%
# generate dataset
X, y = mglearn.datasets.make_forge()
# plot dataset
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape: {}".format(X.shape))
# Out:
# X.shape: (26, 2)

# %% [markdown]
# ### Import make_wave dataset

# %%
X, y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(X, y, 'o')
plt.ylim(-3,3)
plt.xlabel("Feature")
plt.ylabel("Target")
# Out:
# Text(0,0.5,'Target')

# %% [markdown]
# ### Import the breast cancer dataset from sklearn

# %%
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
print("Keys of cancer dataset: {}".format(cancer.keys()))
# Out:
# Keys of cancer dataset: dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# ### Shape of dataset

# %%
print("Shape of cancer data set: {}".format(cancer.data.shape))
# Out:
# Shape of cancer data set: (569, 30)

# %% [markdown]
# ### The amount of data of each type of cancer: M/B

# %%
print("Sample counts per class: {}".format({n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))}))
# Out:
# Sample counts per class: {'malignant': 212, 'benign': 357}

# %% [markdown]
# ### Description of each feature

# %%
print("Features: {}".format(cancer.feature_names))
# Out:
# Features: ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %% [markdown]
# ### Import Boston dataset from sklearn

# %%
from sklearn.datasets import load_boston

boston = load_boston()
print("Keys of boston dataset: {}".format(boston.keys()))
# Out:
# Keys of boston dataset: dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %% [markdown]
# ### Shape of dataset

# %%
print("Shape of boston dataset: {}".format(boston.data.shape))
# Out:
# Shape of boston dataset: (506, 13)

# %%
X, y = mglearn.datasets.load_extended_boston()
print(X.shape)
# Out:
# (506, 104)

# %% [markdown]
# ### The k-NN algorithm

# %%
mglearn.plots.plot_knn_classification(n_neighbors=1)

# %%
mglearn.plots.plot_knn_classification(n_neighbors=3)

# %% [markdown]
# ### k-NN algorithm
#
# ### Importing the dataset and splitting it

# %%
from sklearn.model_selection import train_test_split

X, y = mglearn.datasets.make_forge()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ### Importing the k-NN classifier and instantiating the class with the number of neighbors = 3

# %%
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Creating the model for the classifier

# %%
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %% [markdown]
# ### Predicting new data

# %%
# This is the test dataset for predicting new data
print("Test set predictions: {}".format(clf.predict(X_test)))
# Out:
# Test set predictions: [1 0 1 0 1 0 0]

# %% [markdown]
# ### Accuracy of the classifier

# %%
print("Accuracy: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# Accuracy: 0.86

# %% [markdown]
# ### Analyzing the k-NN classifier

# %%
fig, axes = plt.subplots(1, 3, figsize=(10,3))

for n_neighbors, ax in zip([1, 3, 9], axes):
    # the fit method returns the object self, so we can instantiate
    # and fit in one line
    clf = KNeighborsClassifier(n_neighbors=n_neighbors).fit(X, y)
    mglearn.plots.plot_2d_separator(clf, X, fill=True, eps=0.5, ax=ax, alpha=.4)
    mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)
    ax.set_title("{} neighbor(s)".format(n_neighbors))
    ax.set_xlabel("feature 0")
    ax.set_ylabel("feature 1")
axes[0].legend(loc=3)

# %% [markdown]
# ### k-NN with [n-neighbors = number of train data] results in: all test data will belong to the class that has the higher number of training points and all data points has n-neighbors - all training points

# %%
X_train = [[1.1, 1.2], [2.2, 2.3], [1.3, 1.2], [2.1, 2.5], [2.1, 2.2]]
y_train = [1,2,1,2,2]

clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train)

X_test = [[1.3, 1.1], [2.3, 2.4], [1.0, 1.0], [1.1, 1.1]]
y_test = [1,2,1,1]

print(clf.score(X_test, y_test))
print(clf.predict(X_test))
# Out:
# 0.25
# [2 2 2 2]

# %%
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=66)
training_accuracy = []
test_accuracy = []
# try n_neighbors from 1 to 10
neighbors_settings = range(1, 11)
for n_neighbors in neighbors_settings:
    # build the model
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X_train, y_train)
    # record training set accuracy
    training_accuracy.append(clf.score(X_train, y_train))
    # record generalization accuracy
    test_accuracy.append(clf.score(X_test, y_test))
plt.plot(neighbors_settings, training_accuracy, label="training accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %% [markdown]
# ### k-NN algorithm for regression

# %%
from sklearn.neighbors import KNeighborsRegressor

X, y = mglearn.datasets.make_wave(n_samples=40)
# split the wave dataset into a training and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
# instantiate the model and set the number of neighbors to consider to 3
reg = KNeighborsRegressor(n_neighbors=3)
# fit the model using the training data and training targets
reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#           weights='uniform')

# %% [markdown]
# ### Predicting data with the classifier

# %%
print(format(X_test))

print("Test set predictions:\n{}".format(reg.predict(X_test)))
# Out:
# [[-1.247]
#  [ 0.671]
#  [ 1.711]
#  [-2.064]
#  [-2.876]
#  [-1.9  ]
#  [ 0.554]
#  [ 2.819]
#  [-0.408]
#  [-2.721]]
# Test set predictions:
# [-0.054  0.357  1.137 -1.894 -1.139 -1.631  0.357  0.912 -0.447 -1.139]

# %% [markdown]
# ### Printing the score of the classifier. The number is between 0 and 1
# ### 0 - constant model, 1 - perfect prediction

# %%
print("Test set R^2: {:.2f}".format(reg.score(X_test, y_test)))
# Out:
# Test set R^2: 0.83

# %% [markdown]
# ### Analyzing KNeighborsRegressor

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
# create 1,000 data points, evenly spaced between -3 and 3
line = np.linspace(-3, 3, 1000).reshape(-1, 1)
for n_neighbors, ax in zip([1, 3, 9], axes):
# make predictions using 1, 3, or 9 neighbors
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train, y_train)
    ax.plot(line, reg.predict(line))
    ax.plot(X_train, y_train, '^', c=mglearn.cm2(0), markersize=8)
    ax.plot(X_test, y_test, 'v', c=mglearn.cm2(1), markersize=8)
    ax.set_title("{} neighbor(s)\n train score: {:.2f} test score: {:.2f}".format(n_neighbors, reg.score(X_train, y_train),
            reg.score(X_test, y_test)))
    ax.set_xlabel("Feature")
    ax.set_ylabel("Target")
axes[0].legend(["Model predictions", "Training data/target",
"Test data/target"], loc="best")

# %% [markdown]
# ### 2 important parameters for k-NN: number of neighbors and the distance between the data points.
# #### 1. The number of neighbors need to be adjusted in order to have a good prediction accuracy.
# #### 2. The distance between data points is often the Euclidian distance.

# %% [markdown]
# ### Linear models

# %% [markdown]
# ### Linear regression fof wave dataset

# %%
mglearn.plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804

# %% [markdown]
# ### Linear regression - Ordinary least squared

# %%
from sklearn.linear_model import LinearRegression

X, y = mglearn.datasets.make_wave(n_samples=60)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# ### Paramters weights and offset are stored in coef\_ and intercept\_ attributes

# %%
print("lr.coef_: {}".format(lr.coef_))
print("lr.intercept_: {}".format(lr.intercept_))
# Out:
# lr.coef_: [ 0.394]
# lr.intercept_: -0.031804343026759746

# %% [markdown]
# ### Performance of training and test sets

# %%
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.67
# Test set score: 0.66

# %% [markdown]
# ### Linear regression on Boston Housing Dataset

# %%
X, y = mglearn.datasets.load_extended_boston()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
lr = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# ### Performance of training and test sets

# %%
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.95
# Test set score: 0.61

# %% [markdown]
# ### Ridge regression
